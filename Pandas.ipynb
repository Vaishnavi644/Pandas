# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaishnavi644/Pandas/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
info={
    "Name": ["Pallavi", "Suhani", "Anamika"],
    "CGPA" : [8.8,6.7,7.8]
}
df=pd.DataFrame(info)
print(df, type(df))
# Out:
#       Name  CGPA
# 0  Pallavi   8.8
# 1   Suhani   6.7
# 2  Anamika   7.8 <class 'pandas.core.frame.DataFrame'>

# %%
df
# Out:
#       Name  CGPA
# 0  Pallavi   8.8
# 1   Suhani   6.7
# 2  Anamika   7.8

# %%
s=pd.Series([1,2,3,4,5])
print(s, type(s))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64 <class 'pandas.core.series.Series'>

# %%
#Indexing
print(s[0])
print(s[2])
print(s[4])
# Out:
# 1
# 3
# 5
